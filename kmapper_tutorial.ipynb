# %%
import kmapper as km
from sklearn import datasets

# %matplotlib inline

# %%
data, labels = datasets.make_circles(n_samples=500, noise=0.03, factor=0.3)

# %%
data.shape
# Out:
# (500, 2)

# %%
labels.shape
# Out:
# (500,)

# %%
mapper = km.KeplerMapper(verbose=1)

# %%
projected_data = mapper.fit_transform(data, projection=[0,1])
projected_data.shape
# Out:
# ..Projecting data using: [0, 1]
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
# (500, 2)

# %%
graph = mapper.map(projected_data, data, nr_cubes=10)
graph
# Out:
# Mapping on data shaped (500, 2) using lens shaped (500, 2)
#
# Creating 100 hypercubes.
#
# Created 43 edges and 49 nodes in 0:00:00.046964.
# {'links': defaultdict(list,
#              {'cube17_cluster0': ['cube18_cluster0'],
#               'cube18_cluster0': ['cube28_cluster0'],
#               'cube20_cluster0': ['cube30_cluster0'],
#               'cube29_cluster0': ['cube39_cluster0'],
#               'cube2_cluster0': ['cube3_cluster0', 'cube11_cluster0'],
#               'cube33_cluster0': ['cube34_cluster0', 'cube43_cluster0'],
#               'cube34_cluster0': ['cube35_cluster0'],
#               'cube35_cluster0': ['cube36_cluster0'],
#               'cube3_cluster0': ['cube4_cluster0'],
#               'cube43_cluster0': ['cube53_cluster0'],
#               'cube45_cluster0': ['cube46_cluster0'],
#               'cube46_cluster0': ['cube56_cluster0'],
#               'cube49_cluster0': ['cube59_cluster0'],
#               'cube50_cluster0': ['cube60_cluster0'],
#               'cube53_cluster0': ['cube54_cluster0',
#                'cube63_cluster0',
#                'cube64_cluster0'],
#               'cube54_cluster0': ['cube63_cluster0', 'cube64_cluster0'],
#               'cube55_cluster0': ['cube56_cluster0',
#                'cube65_cluster0',
#                'cube66_cluster0'],
#               'cube56_cluster0': ['cube65_cluster0', 'cube66_cluster0'],
#               'cube59_cluster0': ['cube69_cluster0'],
#               'cube60_cluster0': ['cube70_cluster0'],
#               'cube63_cluster0': ['cube64_cluster0'],
#               'cube64_cluster0': ['cube65_cluster0'],
#               'cube65_cluster0': ['cube66_cluster0'],
#               'cube6_cluster0': ['cube7_cluster0'],
#               'cube70_cluster0': ['cube71_cluster0'],
#               'cube71_cluster0': ['cube81_cluster0'],
#               'cube78_cluster0': ['cube79_cluster0'],
#               'cube7_cluster0': ['cube17_cluster0'],
#               'cube81_cluster0': ['cube82_cluster0'],
#               'cube82_cluster0': ['cube92_cluster0'],
#               'cube87_cluster0': ['cube88_cluster0', 'cube97_cluster0'],
#               'cube94_cluster0': ['cube95_cluster0'],
#               'cube95_cluster0': ['cube96_cluster0'],
#               'cube96_cluster0': ['cube97_cluster0']}),
#  'meta_graph': '[0, 1]',
#  'meta_nodes': defaultdict(list,
#              {'cube11_cluster0': {'coordinates': array([1, 1]), 'size': 10},
#               'cube17_cluster0': {'coordinates': array([1, 7]), 'size': 6},
#               'cube18_cluster0': {'coordinates': array([1, 8]), 'size': 10},
#               'cube20_cluster0': {'coordinates': array([2, 0]), 'size': 8},
#               'cube28_cluster0': {'coordinates': array([2, 8]), 'size': 5},
#               'cube29_cluster0': {'coordinates': array([2, 9]), 'size': 5},
#               'cube2_cluster0': {'coordinates': array([0, 2]), 'size': 11},
#               'cube30_cluster0': {'coordinates': array([3, 0]), 'size': 11},
#               'cube33_cluster0': {'coordinates': array([3, 3]), 'size': 10},
#               'cube34_cluster0': {'coordinates': array([3, 4]), 'size': 31},
#               'cube35_cluster0': {'coordinates': array([3, 5]), 'size': 34},
#               'cube36_cluster0': {'coordinates': array([3, 6]), 'size': 4},
#               'cube39_cluster0': {'coordinates': array([3, 9]), 'size': 12},
#               'cube3_cluster0': {'coordinates': array([0, 3]), 'size': 11},
#               'cube40_cluster0': {'coordinates': array([4, 0]), 'size': 6},
#               'cube43_cluster0': {'coordinates': array([4, 3]), 'size': 36},
#               'cube45_cluster0': {'coordinates': array([4, 5]), 'size': 4},
#               'cube46_cluster0': {'coordinates': array([4, 6]), 'size': 26},
#               'cube49_cluster0': {'coordinates': array([4, 9]), 'size': 8},
#               'cube4_cluster0': {'coordinates': array([0, 4]), 'size': 11},
#               'cube50_cluster0': {'coordinates': array([5, 0]), 'size': 10},
#               'cube53_cluster0': {'coordinates': array([5, 3]), 'size': 28},
#               'cube54_cluster0': {'coordinates': array([5, 4]), 'size': 6},
#               'cube55_cluster0': {'coordinates': array([5, 5]), 'size': 11},
#               'cube56_cluster0': {'coordinates': array([5, 6]), 'size': 32},
#               'cube59_cluster0': {'coordinates': array([5, 9]), 'size': 10},
#               'cube5_cluster0': {'coordinates': array([0, 5]), 'size': 8},
#               'cube60_cluster0': {'coordinates': array([6, 0]), 'size': 10},
#               'cube63_cluster0': {'coordinates': array([6, 3]), 'size': 4},
#               'cube64_cluster0': {'coordinates': array([6, 4]), 'size': 31},
#               'cube65_cluster0': {'coordinates': array([6, 5]), 'size': 29},
#               'cube66_cluster0': {'coordinates': array([6, 6]), 'size': 5},
#               'cube69_cluster0': {'coordinates': array([6, 9]), 'size': 9},
#               'cube6_cluster0': {'coordinates': array([0, 6]), 'size': 9},
#               'cube70_cluster0': {'coordinates': array([7, 0]), 'size': 7},
#               'cube71_cluster0': {'coordinates': array([7, 1]), 'size': 5},
#               'cube78_cluster0': {'coordinates': array([7, 8]), 'size': 5},
#               'cube79_cluster0': {'coordinates': array([7, 9]), 'size': 6},
#               'cube7_cluster0': {'coordinates': array([0, 7]), 'size': 7},
#               'cube81_cluster0': {'coordinates': array([8, 1]), 'size': 11},
#               'cube82_cluster0': {'coordinates': array([8, 2]), 'size': 6},
#               'cube87_cluster0': {'coordinates': array([8, 7]), 'size': 7},
#               'cube88_cluster0': {'coordinates': array([8, 8]), 'size': 8},
#               'cube92_cluster0': {'coordinates': array([9, 2]), 'size': 6},
#               'cube93_cluster0': {'coordinates': array([9, 3]), 'size': 11},
#               'cube94_cluster0': {'coordinates': array([9, 4]), 'size': 8},
#               'cube95_cluster0': {'coordinates': array([9, 5]), 'size': 8},
#               'cube96_cluster0': {'coordinates': array([9, 6]), 'size': 12},
#               'cube97_cluster0': {'coordinates': array([9, 7]), 'size': 8}}),
#  'nodes': defaultdict(list,
#              {'cube11_cluster0': [103,
#                182,
#                209,
#                255,
#                270,
#                299,
#                412,
#                424,
#                428,
#                475],
#               'cube17_cluster0': [82, 92, 109, 289, 383, 415],
#               'cube18_cluster0': [17,
#                109,
#                167,
#                260,
#                282,
#                333,
#                426,
#                427,
#                431,
#                464],
#               'cube20_cluster0': [11, 114, 134, 173, 243, 265, 275, 465],
#               'cube28_cluster0': [16, 100, 333, 397, 464],
#               'cube29_cluster0': [53, 98, 112, 221, 449],
#               'cube2_cluster0': [95,
#                135,
#                176,
#                237,
#                274,
#                299,
#                305,
#                317,
#                320,
#                361,
#                425],
#               'cube30_cluster0': [11,
#                57,
#                66,
#                79,
#                119,
#                170,
#                180,
#                210,
#                275,
#                380,
#                468],
#               'cube33_cluster0': [8,
#                44,
#                186,
#                229,
#                232,
#                337,
#                389,
#                404,
#                458,
#                489],
#               'cube34_cluster0': [50,
#                63,
#                74,
#                78,
#                107,
#                133,
#                144,
#                160,
#                172,
#                195,
#                198,
#                200,
#                257,
#                269,
#                309,
#                326,
#                342,
#                346,
#                350,
#                363,
#                372,
#                389,
#                396,
#                417,
#                422,
#                434,
#                444,
#                463,
#                489,
#                492,
#                493],
#               'cube35_cluster0': [0,
#                1,
#                4,
#                19,
#                24,
#                60,
#                63,
#                76,
#                86,
#                110,
#                127,
#                131,
#                144,
#                145,
#                156,
#                215,
#                227,
#                246,
#                276,
#                304,
#                311,
#                312,
#                324,
#                343,
#                355,
#                394,
#                395,
#                400,
#                438,
#                444,
#                474,
#                482,
#                483,
#                498],
#               'cube36_cluster0': [39, 60, 301, 442],
#               'cube39_cluster0': [53,
#                75,
#                80,
#                98,
#                154,
#                201,
#                352,
#                373,
#                399,
#                419,
#                446,
#                485],
#               'cube3_cluster0': [7,
#                28,
#                37,
#                89,
#                137,
#                142,
#                248,
#                317,
#                331,
#                361,
#                478],
#               'cube40_cluster0': [41, 90, 225, 359, 367, 382],
#               'cube43_cluster0': [8,
#                9,
#                44,
#                101,
#                111,
#                120,
#                126,
#                128,
#                147,
#                155,
#                157,
#                169,
#                186,
#                205,
#                207,
#                218,
#                234,
#                244,
#                251,
#                277,
#                313,
#                318,
#                325,
#                336,
#                349,
#                351,
#                379,
#                387,
#                402,
#                404,
#                406,
#                423,
#                452,
#                456,
#                462,
#                471],
#               'cube45_cluster0': [18, 153, 258, 338],
#               'cube46_cluster0': [18,
#                36,
#                49,
#                73,
#                94,
#                158,
#                179,
#                222,
#                223,
#                241,
#                254,
#                256,
#                261,
#                290,
#                294,
#                322,
#                327,
#                345,
#                405,
#                421,
#                429,
#                455,
#                470,
#                472,
#                473,
#                487],
#               'cube49_cluster0': [23, 38, 93, 163, 271, 356, 418, 484],
#               'cube4_cluster0': [7,
#                30,
#                62,
#                108,
#                166,
#                184,
#                302,
#                331,
#                374,
#                443,
#                450],
#               'cube50_cluster0': [15,
#                105,
#                123,
#                125,
#                211,
#                239,
#                283,
#                398,
#                409,
#                476],
#               'cube53_cluster0': [12,
#                64,
#                85,
#                111,
#                138,
#                140,
#                169,
#                181,
#                194,
#                245,
#                281,
#                285,
#                291,
#                292,
#                357,
#                368,
#                376,
#                377,
#                384,
#                388,
#                430,
#                435,
#                460,
#                462,
#                469,
#                491,
#                497,
#                499],
#               'cube54_cluster0': [77, 308, 401, 408, 430, 439],
#               'cube55_cluster0': [25,
#                33,
#                130,
#                149,
#                187,
#                190,
#                293,
#                303,
#                330,
#                371,
#                413],
#               'cube56_cluster0': [5,
#                34,
#                40,
#                61,
#                69,
#                72,
#                88,
#                97,
#                113,
#                149,
#                187,
#                204,
#                235,
#                238,
#                242,
#                256,
#                262,
#                263,
#                287,
#                328,
#                330,
#                339,
#                353,
#                371,
#                378,
#                405,
#                420,
#                421,
#                433,
#                470,
#                472,
#                477],
#               'cube59_cluster0': [2, 43, 83, 93, 214, 316, 418, 440, 451, 496],
#               'cube5_cluster0': [104, 162, 164, 217, 252, 253, 332, 390],
#               'cube60_cluster0': [56,
#                59,
#                87,
#                99,
#                171,
#                185,
#                192,
#                259,
#                319,
#                398],
#               'cube63_cluster0': [26, 292, 364, 430],
#               'cube64_cluster0': [3,
#                13,
#                20,
#                26,
#                35,
#                47,
#                55,
#                77,
#                150,
#                159,
#                206,
#                212,
#                213,
#                231,
#                273,
#                297,
#                310,
#                341,
#                358,
#                362,
#                366,
#                381,
#                401,
#                407,
#                416,
#                430,
#                432,
#                437,
#                459,
#                486,
#                494],
#               'cube65_cluster0': [29,
#                51,
#                55,
#                58,
#                122,
#                130,
#                139,
#                177,
#                183,
#                187,
#                199,
#                216,
#                233,
#                247,
#                266,
#                268,
#                298,
#                303,
#                341,
#                369,
#                413,
#                414,
#                436,
#                441,
#                445,
#                447,
#                453,
#                454,
#                459],
#               'cube66_cluster0': [72, 183, 187, 263, 347],
#               'cube69_cluster0': [54, 81, 83, 146, 151, 250, 403, 410, 490],
#               'cube6_cluster0': [136, 193, 196, 230, 267, 278, 286, 295, 386],
#               'cube70_cluster0': [56, 117, 121, 124, 329, 448, 457],
#               'cube71_cluster0': [67, 117, 143, 249, 448],
#               'cube78_cluster0': [102, 174, 365, 385, 411],
#               'cube79_cluster0': [21, 132, 306, 354, 365, 385],
#               'cube7_cluster0': [45, 70, 92, 136, 165, 288, 383],
#               'cube81_cluster0': [10,
#                67,
#                91,
#                116,
#                148,
#                188,
#                219,
#                272,
#                321,
#                344,
#                461],
#               'cube82_cluster0': [106, 148, 178, 340, 375, 481],
#               'cube87_cluster0': [115, 189, 191, 224, 264, 307, 467],
#               'cube88_cluster0': [31, 71, 84, 129, 315, 348, 467, 495],
#               'cube92_cluster0': [65, 106, 152, 178, 334, 375],
#               'cube93_cluster0': [42,
#                52,
#                118,
#                202,
#                203,
#                208,
#                236,
#                240,
#                370,
#                480,
#                488],
#               'cube94_cluster0': [14, 32, 96, 141, 226, 284, 300, 391],
#               'cube95_cluster0': [6, 27, 32, 46, 175, 323, 335, 479],
#               'cube96_cluster0': [27,
#                48,
#                68,
#                168,
#                197,
#                279,
#                280,
#                296,
#                314,
#                360,
#                392,
#                393],
#               'cube97_cluster0': [22, 48, 68, 161, 228, 307, 314, 393]})}

# %%
mapper.visualize(graph, path_html="make_circles_keplermapper_output.html", 
                 title="make_circles(n_samples=5000, noise=0.03, factor=0.3)")
# Out:
# Wrote d3.js graph to 'make_circles_keplermapper_output.html'
